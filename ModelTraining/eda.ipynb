# %% [markdown]
# # Loading the Unsplash Research dataset in Pandas dataframes
#
# This notebooks is an example of how to load the Unsplash Research dataset in Pandas dataframes for analysis.

# %% [markdown]
# ## Loading libraries

# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# ## Loading the datasets in Pandas
#
# Make sure that you correctly point to the correct path.

# %%
path = 'unsplash-research-dataset-lite-latest/'
documents = ['photos', 'keywords', 'collections', 'conversions']
datasets = {}

for doc in documents:
  files = glob.glob(path + doc + ".tsv*")

  subsets = []
  for filename in files:
    df = pd.read_csv(filename, sep='\t', header=0)
    subsets.append(df)

  datasets[doc] = pd.concat(subsets, axis=0, ignore_index=True)

# %% [markdown]
# ## Exploring the datasets
#
# Here are the first couple of rows from each dataset, as an example.
#
# Enjoy the exploration!

# %%
datasets['photos'].head()
# Out:
#       photo_id                                photo_url  \
# 0  r3ZWnitp3zk  https://unsplash.com/photos/r3ZWnitp3zk
# 1  -Y-XzY0HhEM  https://unsplash.com/photos/-Y-XzY0HhEM
# 2  mwhklqGVzck  https://unsplash.com/photos/mwhklqGVzck
# 3  HZg0vJHFyg0  https://unsplash.com/photos/HZg0vJHFyg0
# 4  8CDzJFF10d0  https://unsplash.com/photos/8CDzJFF10d0
#
#                                      photo_image_url   photo_submitted_at  \
# 0  https://images.unsplash.com/photo-141582700792...  2014-11-12 21:17:08
# 1  https://images.unsplash.com/photo-141452120399...  2014-10-28 18:47:58
# 2  https://images.unsplash.com/photo-141757709743...  2014-12-03 03:29:29
# 3  https://images.unsplash.com/uploads/1411041301...  2014-09-18 11:55:40
# 4  https://images.unsplash.com/photo-142840615360...  2015-04-07 11:29:37
#
#   photo_featured photographer_username photographer_first_name  \
# 0              t              envisual                 Charlie
# 1              t              cindydvr                   cindy
# 2              t              juskteez                Juskteez
# 3              t           garyrockett                    Gary
# 4              t               olliepb            Oliver & Hen
#
#   photographer_last_name   exif_camera_make exif_camera_model  ...  \
# 0                   Hang  NIKON CORPORATION       NIKON D3200  ...
# 1              del valle          Panasonic           DMC-SZ1  ...
# 2                     Vu           FUJIFILM              X-S1  ...
# 3                Rockett                NaN               NaN  ...
# 4      Pritchard-Barrett  NIKON CORPORATION         NIKON D90  ...
#
#    photo_location_longitude photo_location_country photo_location_city  \
# 0                       NaN                    NaN                 NaN
# 1                       NaN                    NaN                 NaN
# 2                       NaN                    NaN                 NaN
# 3                       NaN                    NaN                 NaN
# 4                       NaN                    NaN                 NaN
#
#   stats_views stats_downloads                         ai_description  \
# 0      961314            3119  brown rock formation on body of water
# 1     9014666           46486       body of water during golden hour
# 2    13289509          216806                                 galaxy
# 3     1517759            8713       brown and white cattle in forest
# 4     1685804            7798  pelican flying under white cloudy sky
#
#    ai_primary_landmark_name ai_primary_landmark_latitude  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   ai_primary_landmark_longitude  ai_primary_landmark_confidence
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
# [5 rows x 26 columns]

# %%
datasets['keywords'].head()
# Out:
#       photo_id   keyword  ai_service_1_confidence  ai_service_2_confidence  \
# 0  zzux2cH-F-A       hat                34.696083                      NaN
# 1  zzux2cH-F-A       fog                41.619389                      NaN
# 2  zzux2cH-F-A  arenaria                40.862339                      NaN
# 3  zzux2cH-F-A      mist                40.306744                      NaN
# 4  zzux2cH-F-A       ice                60.944134                      NaN
#
#   suggested_by_user
# 0                 f
# 1                 f
# 2                 f
# 3                 f
# 4                 f

# %%
datasets['collections'].head()
# Out:
#       photo_id  collection_id    collection_title   photo_collected_at
# 0  --2IBUMom1I        4668070                Pose  2019-04-18 23:59:25
# 1  --2IBUMom1I         162470  Majestical Sunsets  2016-03-15 17:04:25
# 2  --2IBUMom1I        4472213              People  2019-03-17 04:44:02
# 3  --2IBUMom1I        2143051     Travel / Places  2018-05-22 23:20:05
# 4  --2IBUMom1I        3734077              Images  2018-12-30 00:56:45

# %%
datasets['conversions'].head()
# Out:
#           converted_at conversion_type            keyword     photo_id  \
# 0  2020-02-28 17:53:59        download   ancient cave art  5vV1xgPPdoI
# 1  2020-02-28 18:00:43        download               bali  -zxG8fyqCg0
# 2  2020-02-28 18:08:42        download              water  ebbFZvavGy4
# 3  2020-02-28 18:10:22        download             jungle  nNNxBHA4ops
# 4  2020-02-28 18:14:33        download  simple background  RAVdOqWXPvg
#
#                       anonymous_user_id conversion_country
# 0  9dfbbbda-cf6c-4bf8-b519-9082d82e46ce                 US
# 1  11a88646-226c-4ff0-a0e6-0ad1870f5422                 IN
# 2  38a51244-0dae-4ee2-b08b-446899879e3a                 US
# 3  a85b3b56-9fcd-4846-a8ac-e232d9cfd912                 AR
# 4  4fc76af5-e8f7-459b-8b6a-a0539dc26e10                 HU

# %%
datasets['photos']["photo_image_url"][0]
# Out:
# 'https://images.unsplash.com/photo-1415827007927-b636e96fec40'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
datasets['photos']["stats_views"].describe()
# Out:
# count    2.500000e+04
# mean     1.394069e+06
# std      2.927277e+06
# min      2.831700e+04
# 25%      2.539570e+05
# 50%      5.477885e+05
# 75%      1.114180e+06
# max      1.003223e+08
# Name: stats_views, dtype: float64

# %%
datasets['photos']["stats_views"].head(5)
# Out:
# 0      961314
# 1     9014666
# 2    13289509
# 3     1517759
# 4     1685804
# Name: stats_views, dtype: int64

# %%
datasets['photos']["stats_downloads"].describe()
# Out:
# count    2.500000e+04
# mean     6.955217e+03
# std      2.317060e+04
# min      1.220000e+02
# 25%      1.182000e+03
# 50%      1.990500e+03
# 75%      5.233250e+03
# max      1.419358e+06
# Name: stats_downloads, dtype: float64

# %%
datasets['photos']["photo_featured"].describe()
# Out:
# count     25000
# unique        1
# top           t
# freq      25000
# Name: photo_featured, dtype: object

# %%
sns.distplot(datasets['photos']["stats_views"])
# Out:
# <AxesSubplot:xlabel='stats_views'>

# %%
sns.distplot(datasets['photos']["stats_downloads"])
# Out:
# <AxesSubplot:xlabel='stats_downloads'>
